# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
accuracy_list = np.loadtxt("delta_accuracy.csv", delimiter=",")

plt.plot(accuracy_list[0:1000, 0], accuracy_list[0:1000, 1])
plt.show()

# %%
delta_list = np.loadtxt("delta_error.csv", delimiter=",")

plt.plot(delta_list[0:1000, 0], delta_list[0:1000, 1])
plt.show()
